# %% [markdown]
# <a href="https://colab.research.google.com/github/SumathiGit/Image-Captioning-Pytorch/blob/main/COCO%20Captioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pdollar/coco.git
# Out:
# Cloning into 'coco'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 24.25 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd coco/PythonAPI/
# Out:
# /content/coco/PythonAPI

# %%
# !make

# %%
# !python setup.py build
# !python setup.py install

# %%
cd ../../
# Out:
# /content

# %%
# !git clone https://github.com/yunjey/pytorch-tutorial.git
# Out:
# Cloning into 'pytorch-tutorial'...
# remote: Enumerating objects: 917, done.
# remote: Total 917 (delta 0), reused 0 (delta 0), pack-reused 917
# Receiving objects: 100% (917/917), 12.80 MiB | 10.97 MiB/s, done.
# Resolving deltas: 100% (490/490), done.

# %%
cd pytorch-tutorial/tutorials/03-advanced/image_captioning/
# Out:
# /content/pytorch-tutorial/tutorials/03-advanced/image_captioning

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import cv2

testim = imread('png/example.png')
figure()
imshow(testim)
plt.show()

# !python sample.py --image='png/example.png'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************
# <start> a group of giraffes standing next to each other . <end>
# *****************************************
# <Figure size 640x480 with 1 Axes>

# %%
# %matplotlib inline
import cv2

testim = imread('png/frame.jpg')
figure()
imshow(testim)
plt.show()


# !python sample.py --image='png/frame.jpg'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************
# <start> a man and a woman are walking down a street . <end>
# *****************************************
# <Figure size 640x480 with 1 Axes>

# %%
# %matplotlib inline
import cv2

testim = imread('png/frame1.jpg')
figure()
imshow(testim)
plt.show()


# !python sample.py --image='png/frame1.jpg'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************
# <start> a man is walking down a street holding a skateboard . <end>
# *****************************************
# <Figure size 640x480 with 1 Axes>

# %%
# %matplotlib inline
import cv2

testim = imread('png/frame2.jpg')
figure()
imshow(testim)
plt.show()
# !python sample.py --image='png/frame2.jpg'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************
# <start> a street corner with a lot of cars and a street sign . <end>
# *****************************************
# <Figure size 640x480 with 1 Axes>

# %%
# %matplotlib inline
import cv2

testim = imread('png/frame4.jpg')
figure()
imshow(testim)
plt.show()

# !python sample.py --image='png/frame4.jpg'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************
# <start> a man is standing on a skateboard in the street . <end>
# *****************************************
# <Figure size 640x480 with 1 Axes>

# %%
""" https://github.com/yunjey/pytorch-tutorial/tree/master/tutorials/03-advanced/image_captioning """ Testing images with a pre-trained model
